# %%
import torch
import pandas as pd
import numpy as np
from Neural_Nets.Classification.ClassificationDataset.Development.ClassificationDataset import *

# %%
seq_len = 5
measurement = 'C'

dc = DatasetCreator(r"C:\Users\danie\Documents\Montanuni\Masterarbeit\4_Daten\Elements.xlsx", elements=None, 
                   splits=(0.8, 0.2), validation=False, seq_len=seq_len, measurement=measurement, stable_only=True)
# Out:
# C
# Ag
#       Temperature  Measurements
# 0           299.0     25.399605
# 1           300.0     25.402830
# 2           301.0     25.406078
# 3           302.0     25.409348
# 4           303.0     25.412640
# ...           ...           ...
# 1696       1995.0     33.472000
# 1697       1996.0     33.472000
# 1698       1997.0     33.472000
# 1699       1998.0     33.472000
# 1700       1999.0     33.472000
#
# [1701 rows x 2 columns]
# C
# Al
#       Temperature  Measurements
# 0           299.0     24.307489
# 1           300.0     24.325443
# 2           301.0     24.343300
# 3           302.0     24.361059
# 4           303.0     24.378719
# ...           ...           ...
# 1696       1995.0     31.748192
# 1697       1996.0     31.748192
# 1698       1997.0     31.748192
# 1699       1998.0     31.748192
# 1700       1999.0     31.748192
#
# [1701 rows x 2 columns]
# C
# As
#      Temperature  Measurements
# 0          299.0     24.679140
# 1          300.0     24.686300
# 2          301.0     24.693443
# 3          302.0     24.700567
# 4          303.0     24.707676
# ..           ...           ...
# 897       1196.0     29.216038
# 898       1197.0     29.216038
# 899       1198.0     29.216038
# 900       1199.0     29.216038
# 901       1200.0     29.216038
#
# [902 rows x 2 columns]
# C
# Au
#       Temperature  Measurements
# 0           299.0     25.420191
# 1           300.0     25.422810
# 2           301.0     25.425459
# 3           302.0     25.428141
# 4           303.0     25.430855
# ...           ...           ...
# 1696       1995.0     30.961599
# 1697       1996.0     30.961599
# 1698       1997.0     30.961599
# 1699       1998.0     30.961599
# 1700       1999.0     30.961599
#
# [1701 rows x 2 columns]
# C
# B
#       Temperature  Measurements
# 0           299.0     11.140939
# 1           300.0     11.207659
# 2           301.0     11.273823
# 3           302.0     11.339437
# 4           303.0     11.404509
# ...           ...           ...
# 1696       1995.0     29.520933
# 1697       1996.0     29.524021
# 1698       1997.0     29.527109
# 1699       1998.0     29.530195
# 1700       1999.0     29.533281
#
# [1701 rows x 2 columns]
# C
# Ba
#       Temperature  Measurements
# 0           299.0     28.192905
# 1           300.0     28.301670
# 2           301.0     28.409386
# 3           302.0     28.516071
# 4           303.0     28.621738
# ...           ...           ...
# 1696       1995.0     36.508080
# 1697       1996.0     36.503769
# 1698       1997.0     36.499462
# 1699       1998.0     36.495152
# 1700       1999.0     36.490845
#
# [1701 rows x 2 columns]
# C
# Be
#       Temperature  Measurements
# 0           299.0     16.422470
# 1           300.0     16.472469
# 2           301.0     16.522034
# 3           302.0     16.571175
# 4           303.0     16.619890
# ...           ...           ...
# 1696       1995.0     29.722902
# 1697       1996.0     29.725052
# 1698       1997.0     29.727200
# 1699       1998.0     29.729349
# 1700       1999.0     29.731499
#
# [1701 rows x 2 columns]
# C
# Bi
#       Temperature  Measurements
# 0           299.0     25.526937
# 1           300.0     25.532383
# 2           301.0     25.537930
# 3           302.0     25.543575
# 4           303.0     25.549324
# ...           ...           ...
# 1696       1995.0     27.195999
# 1697       1996.0     27.195999
# 1698       1997.0     27.195999
# 1699       1998.0     27.195999
# 1700       1999.0     27.195999
#
# [1701 rows x 2 columns]
# C
# C
# 0           299.0     28.085810
# 1           300.0     28.088669
# 2           301.0     28.091524
# 3           302.0     28.094378
# 4           303.0     28.097229
# ...           ...           ...
# 1696       1995.0     38.702000
# 1697       1996.0     38.702000
# 1698       1997.0     38.702000
# 1699       1998.0     38.702000
# 1700       1999.0     38.702000
#
# [1701 rows x 2 columns]
# C
# Eu
#       Temperature  Measurements
# 0           299.0     26.121367
# 1           300.0     26.132425
# 2           301.0     26.143379
# 3           302.0     26.154232
# 4           303.0     26.164986
# ...           ...           ...
# 1597       1896.0     38.116241
# 1598       1897.0     38.116241
# 1599       1898.0     38.116241
# 1600       1899.0     38.116241
# 1601       1900.0     38.116241
#
# [1602 rows x 2 columns]
# C
# Fe
#       Temperature  Measurements
# 0           299.0     24.865646
# 1           300.0     24.890408
# 2           301.0     24.915083
# 3           302.0     24.939672
# 4           303.0     24.964182
# ...           ...           ...
# 1508       1807.0     41.314514
# 1509       1808.0     41.322422
# 1510       1809.0     41.330334
# 1511       1810.0     41.338261
# 1512       1811.0     46.000019
#
# [1513 rows x 2 columns]
# C
# Ga
#       Temperature  Measurements
# 0           201.0     23.876213
# 1           202.0     23.923714
# 2           203.0     23.969475
# 3           204.0     24.013542
# 4           205.0     24.055992
# ...           ...           ...
# 1794       1995.0     26.487196
# 1795       1996.0     26.487797
# 1796       1997.0     26.488400
# 1797       1998.0     26.489002
# 1798       1999.0     26.489605
#
# [1799 rows x 2 columns]
# C
# Gd
#       Temperature  Measurements
# 0           201.0     34.416718
# 1           202.0     34.548828
# 2           203.0     34.682755
# 3           204.0     34.818512
# 4           205.0     34.956139
# ...           ...           ...
# 1794       1995.0     38.507500
# 1795       1996.0     38.507500
# 1796       1997.0     38.507500
# 1797       1998.0     38.507500
# 1798       1999.0     38.507500
#
# [1799 rows x 2 columns]
# C
# Ge
#       Temperature  Measurements
# 0           299.0     23.362722
# 1           300.0     23.381340
# 2           301.0     23.399734
# 3           302.0     23.417908
# 4           303.0     23.435862
# ...           ...           ...
# 1696       1995.0     27.614401
# 1697       1996.0     27.614401
# 1698       1997.0     27.614401
# 1699       1998.0     27.614401
# 1700       1999.0     27.614401
#
# [1701 rows x 2 columns]
# C
# Hf
#       Temperature  Measurements
# 0           299.0     25.692514
# 1           300.0     25.697445
# 2           301.0     25.702410
# 3           302.0     25.707407
# 4           303.0     25.712437
# ...           ...           ...
# 1696       1995.0     39.273361
# 1697       1996.0     39.281654
# 1698       1997.0     39.289948
# 1699       1998.0     39.298241
# 1700       1999.0     39.306534
#
# [1701 rows x 2 columns]
# C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2cee895fedad> in <module>
#       2 measurement = 'C'
#       3
# ----> 4 dc = DatasetCreator(r"C:\Users\danie\Documents\Montanuni\Masterarbeit\4_Daten\Elements.xlsx", elements=None,
#       5                    splits=(0.8, 0.2), validation=False, seq_len=seq_len, measurement=measurement, stable_only=True)
#
# ~\Documents\Montanuni\Masterarbeit\5_Programmcodes\Neural_Nets\Classification\ClassificationDataset\Development\ClassificationDataset.py in __init__(self, element_phase_filename, temp_range, measurement, seq_len, splits, validation, elements, stable_only)
#      66
#      67             # Create the data
# ---> 68             edc = ElementDatasetCreator(label_range, element=phases_per_element.index[i], temp_range=temp_range,
#      69                                         measurement=measurement, seq_len=seq_len, splits=splits, validation=validation,
#      70                                         stable_only=stable_only)
#
# ~\Documents\Montanuni\Masterarbeit\5_Programmcodes\Neural_Nets\Classification\ClassificationDataset\Development\ClassificationDataset.py in __init__(self, label_range, element, temp_range, measurement, seq_len, splits, validation, stable_only)
#     186         else:
#     187             print(measurement)
# --> 188             sgte_handler.get_stable_properties(temp_range[0], temp_range[1], measurement=measurement)
#     189             self.data = sgte_handler.measurements
#     190
#
# ~\Documents\Montanuni\Masterarbeit\5_Programmcodes\Data_Handling\SGTEHandler\Development\SGTEHandler.py in get_stable_properties(self, start_temp, end_temp, p, measurement)
#     176
#     177         # Evaluate the equations for the Gibbs energy and if selected another property
# --> 178         self.evaluate_equations(start_temp, end_temp, p, gibbs=True, entropy=entropy, enthalpy=enthalpy,
#     179                                 heat_capacity=heat_cap, plot=False, phases=['all'])
#     180
#
# ~\Documents\Montanuni\Masterarbeit\5_Programmcodes\Data_Handling\SGTEHandler\Development\SGTEHandler.py in evaluate_equations(self, start_temp, end_temp, p, gibbs, entropy, enthalpy, heat_capacity, plot, phases, step)
#     125         for i, phase in enumerate(self.selected_phases):
#     126             # Get the Gibbs energies for the temperature range
# --> 127             equation_result = self.solve_equations(phase, p, temp_range, gibbs, entropy, enthalpy, heat_capacity)
#     128             # Plot the obtained data
#     129             if plot:
#
# ~\Documents\Montanuni\Masterarbeit\5_Programmcodes\Data_Handling\SGTEHandler\Development\SGTEHandler.py in solve_equations(self, phase, p, temp, gibbs, entropy, enthalpy, heat_capacity)
#     259         # Allow for temperature ranges which go over the intervals specified in SGTE data. For this, it is necessary to
#     260         # split the temperature range in order to be able to compute the equations accordingly.
# --> 261         temp_ranges = self.get_temp_ranges(data, temp)
#     262
#     263         # Collection of the obtained data
#
# ~\Documents\Montanuni\Masterarbeit\5_Programmcodes\Data_Handling\SGTEHandler\Development\SGTEHandler.py in get_temp_ranges(data, temp)
#     349         temp_ranges = []
#     350         # First remove all temperature values below the lowest starting temperatures
# --> 351         temp = temp[temp >= data['Start temperature'].min()]
#     352         # Then remove all temperature values which are above the highest end temperatures
#     353         temp = temp[temp <= data['End temperature'].max()]
#
# ~\anaconda3\envs\5_Programmcodes\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3425                 if isinstance(self.columns, MultiIndex):
#    3426                     return self._getitem_multilevel(key)
# -> 3427                 return self._get_item_cache(key)
#    3428
#    3429         # Do we have a slicer (on rows)?
#
# ~\anaconda3\envs\5_Programmcodes\lib\site-packages\pandas\core\frame.py in _get_item_cache(self, item)
#    3883
#    3884             loc = self.columns.get_loc(item)
# -> 3885             values = self._mgr.iget(loc)
#    3886             res = self._box_col_values(values, loc).__finalize__(self)
#    3887
#
# ~\anaconda3\envs\5_Programmcodes\lib\site-packages\pandas\core\internals\managers.py in iget(self, i)
#     979         Return the data as a SingleBlockManager.
#     980         """
# --> 981         block = self.blocks[self.blknos[i]]
#     982         values = block.iget(self.blklocs[i])
#     983
#
# ~\anaconda3\envs\5_Programmcodes\lib\site-packages\pandas\core\internals\managers.py in blknos(self)
#     168         if self._blknos is None:
#     169             # Note: these can be altered by other BlockManager methods.
# --> 170             self._rebuild_blknos_and_blklocs()
#     171
#     172         return self._blknos
#
# ~\anaconda3\envs\5_Programmcodes\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     234             rl = blk.mgr_locs
#     235             new_blknos[rl.indexer] = blkno
# --> 236             new_blklocs[rl.indexer] = np.arange(len(rl))
#     237
#     238         if (new_blknos == -1).any():
#
# KeyboardInterrupt:
