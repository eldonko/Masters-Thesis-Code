# %%
from ThermoNet.Development.ThermoNetTorch import ThermoNet, ThermoLossFunc, ThermoDataset
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
from torch.optim import Rprop
from SGTEHandler.Development.SGTEHandler import SGTEHandler
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def epoch(net: ThermoNet, dataloader, loss_func, optimizer):
    epoch_losses = np.zeros([len(dataloader), ])

    for i, (temp, g, s, h, c) in enumerate(dataloader):
        temp = temp.unsqueeze(-1)

        # Forward pass
        gibbs_energy = net(temp)
        
        scale = 10000
        gibbs_energy = gibbs_energy/scale
        g = g/scale
        
        gibbs_not_nan = ~(torch.isnan(gibbs_energy) | torch.isinf(gibbs_energy))
        
        g = g.unsqueeze(-1)

        # Get the loss
        loss = loss_func(gibbs_energy[gibbs_not_nan].float(), g[gibbs_not_nan].float())

        # Backward pass
        net.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(net.parameters(), 100)
        optimizer.step()
        epoch_losses[i] = loss

    mean_epoch_loss = epoch_losses.mean()
    print('Mean epoch loss: ', mean_epoch_loss)
    return mean_epoch_loss

# %%
def train(net, element, phase):
    # Hyperparameters
    n_epochs = 100
    lr = 0.01
    batch_size = 16

    # Data
    dataset = ThermoDataset(element, phase)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # Optimizer
    optimizer = Rprop(net.parameters(), lr=lr)
    loss_func = ThermoLossFunc()

    losses = []

    for i in range(n_epochs):
        print('-----\nEpoch %i:\n' % i)
        loss = epoch(net, dataloader, loss_func, optimizer)
        losses.append(loss)

# %%
def graphic_evaluation(net, element, phase):
    start_temp = 500
    end_temp = 1500
    temp_range = torch.tensor(list(range(start_temp, end_temp)), dtype=torch.float64).unsqueeze(-1)

    # Get true data
    sgte_handler = SGTEHandler(element)
    sgte_handler.evaluate_equations(start_temp, end_temp, 1e5, plot=False, phases=phase, entropy=True, enthalpy=True,
                                    heat_capacity=True)
    data = sgte_handler.equation_result_data

    # Get values
    temp = torch.tensor(data['Temperature'], dtype=torch.float64)
    gibbs = torch.tensor(data.iloc[:, 1])
    entropy = torch.tensor(data.iloc[:, 2])
    enthalpy = torch.tensor(data.iloc[:, 3])
    heat_cap = torch.tensor(data.iloc[:, 4])

    gibbs_pred, entropy_pred, enthalpy_pred, heat_cap_pred = net(temp_range, temp_range, temp_range, temp_range)

    gibbs_pred = gibbs_pred.detach()
    entropy_pred = entropy_pred.detach()
    enthalpy_pred = enthalpy_pred.detach()
    heat_cap_pred = heat_cap_pred.detach()

    plt.figure()
    plt.plot(temp, gibbs)
    plt.grid()
    plt.scatter(temp_range, gibbs_pred, s=0.3, c='red')

    plt.figure()
    plt.plot(temp, entropy)
    plt.grid()
    plt.scatter(temp_range, entropy_pred, s=0.3, c='red')

    plt.figure()
    plt.plot(temp, enthalpy)
    plt.grid()
    plt.scatter(temp_range, enthalpy_pred, s=0.3, c='red')

    plt.figure()
    plt.plot(temp, heat_cap)
    plt.grid()
    plt.scatter(temp_range, heat_cap_pred, s=0.3, c='red')
    plt.show()

# %%
net = ThermoNet()

element = 'Fe'
phase = ['BCC_A2']
train(net, element, phase)
# Out:
# Fe successfully selected!
#
# -----
# Epoch 0:
# C:\Users\danie\anaconda3\envs\5_Programmcodes\lib\site-packages\torch\nn\modules\loss.py:431: UserWarning: Using a target size (torch.Size([14, 1])) that is different to the input size (torch.Size([14])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\danie\anaconda3\envs\5_Programmcodes\lib\site-packages\torch\nn\modules\loss.py:431: UserWarning: Using a target size (torch.Size([12, 1])) that is different to the input size (torch.Size([12])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Mean epoch loss:  nan
# -----
# Epoch 1:
#
# Mean epoch loss:  1.1200345917300225
# -----
# Epoch 2:
#
# Mean epoch loss:  0.8119328414507767
# -----
# Epoch 3:
#
# Mean epoch loss:  0.7385493913822085
# -----
# Epoch 4:
#
# Mean epoch loss:  0.757955862365872
# -----
# Epoch 5:
#
# Mean epoch loss:  0.7626600719849083
# -----
# Epoch 6:
#
# Mean epoch loss:  0.7717863237746408
# -----
# Epoch 7:
#
# Mean epoch loss:  0.7707656155401301
# -----
# Epoch 8:
#
# Mean epoch loss:  0.7540189986961467
# -----
# Epoch 9:
#
# Mean epoch loss:  0.7617270146435666
# -----
# Epoch 10:
#
# Mean epoch loss:  0.7715237351639248
# -----
# Epoch 11:
#
# Mean epoch loss:  0.7556691054150323
# -----
# Epoch 12:
#
# Mean epoch loss:  0.7720411406812545
# -----
# Epoch 13:
#
# Mean epoch loss:  0.7837357243227068
# -----
# Epoch 14:
#
# Mean epoch loss:  0.7472779081664352
# -----
# Epoch 15:
#
# Mean epoch loss:  0.7585295582555722
# -----
# Epoch 16:
#
# Mean epoch loss:  nan
# -----
# Epoch 17:
#
# Mean epoch loss:  0.7770577980832101
# -----
# Epoch 18:
#
# Mean epoch loss:  0.7567352392127581
# -----
# Epoch 19:
#
# Mean epoch loss:  0.7539060876539377
# -----
# Epoch 20:
#
# Mean epoch loss:  0.7437265879152534
# -----
# Epoch 21:
#
# Mean epoch loss:  0.7850462258140617
# -----
# Epoch 22:
#
# Mean epoch loss:  0.7145548194503221
# -----
# Epoch 23:
#
# Mean epoch loss:  0.768832221009255
# -----
# Epoch 24:
#
# Mean epoch loss:  0.7384003659832143
# -----
# Epoch 25:
#
# Mean epoch loss:  nan
# -----
# Epoch 26:
#
# Mean epoch loss:  nan
# -----
# Epoch 27:
#
# Mean epoch loss:  nan
# -----
# Epoch 28:
#
# Mean epoch loss:  nan
# -----
# Epoch 29:
#
# Mean epoch loss:  0.19859137356490175
# -----
# Epoch 30:
#
# Mean epoch loss:  nan
# -----
# Epoch 31:
#
# Mean epoch loss:  nan
# -----
# Epoch 32:
#
# Mean epoch loss:  nan
# -----
# Epoch 33:
#
# Mean epoch loss:  0.18994155297900123
# -----
# Epoch 34:
#
# Mean epoch loss:  nan
# -----
# Epoch 35:
#
# Mean epoch loss:  nan
# -----
# Epoch 36:
#
# Mean epoch loss:  nan
# -----
# Epoch 37:
#
# Mean epoch loss:  0.1926686550012113
# -----
# Epoch 38:
#
# Mean epoch loss:  nan
# -----
# Epoch 39:
#
# Mean epoch loss:  nan
# -----
# Epoch 40:
#
# Mean epoch loss:  nan
# -----
# Epoch 41:
#
# Mean epoch loss:  nan
# -----
# Epoch 42:
#
# Mean epoch loss:  0.20206050500224745
# -----
# Epoch 43:
#
# Mean epoch loss:  nan
# -----
# Epoch 44:
#
# Mean epoch loss:  0.19629375169610727
# -----
# Epoch 45:
#
# Mean epoch loss:  nan
# -----
# Epoch 46:
#
# Mean epoch loss:  nan
# -----
# Epoch 47:
#
# Mean epoch loss:  0.2034663231608188
# -----
# Epoch 48:
#
# Mean epoch loss:  0.20111353942040772
# -----
# Epoch 49:
#
# Mean epoch loss:  nan
# -----
# Epoch 50:
#
# Mean epoch loss:  nan
# -----
# Epoch 51:
#
# Mean epoch loss:  0.20101956918696376
# -----
# Epoch 52:
#
# Mean epoch loss:  nan
# -----
# Epoch 53:
#
# Mean epoch loss:  nan
# -----
# Epoch 54:
#
# Mean epoch loss:  nan
# -----
# Epoch 55:
#
# Mean epoch loss:  nan
# -----
# Epoch 56:
#
# Mean epoch loss:  nan
# -----
# Epoch 57:
#
# Mean epoch loss:  nan
# -----
# Epoch 58:
#
# Mean epoch loss:  nan
# -----
# Epoch 59:
#
# Mean epoch loss:  nan
# -----
# Epoch 60:
#
# Mean epoch loss:  nan
# -----
# Epoch 61:
#
# Mean epoch loss:  0.197467804320644
# -----
# Epoch 62:
#
# Mean epoch loss:  nan
# -----
# Epoch 63:
#
# Mean epoch loss:  nan
# -----
# Epoch 64:
#
# Mean epoch loss:  nan
# -----
# Epoch 65:
#
# Mean epoch loss:  nan
# -----
# Epoch 66:
#
# Mean epoch loss:  0.1919367832934623
# -----
# Epoch 67:
#
# Mean epoch loss:  nan
# -----
# Epoch 68:
#
# Mean epoch loss:  nan
# -----
# Epoch 69:
#
# Mean epoch loss:  nan
# -----
# Epoch 70:
#
# Mean epoch loss:  nan
# -----
# Epoch 71:
#
# Mean epoch loss:  nan
# -----
# Epoch 72:
#
# Mean epoch loss:  nan
# -----
# Epoch 73:
#
# Mean epoch loss:  nan
# -----
# Epoch 74:
#
# Mean epoch loss:  nan
# -----
# Epoch 75:
#
# Mean epoch loss:  nan
# -----
# Epoch 76:
#
# Mean epoch loss:  nan
# -----
# Epoch 77:
#
# Mean epoch loss:  nan
# -----
# Epoch 78:
#
# Mean epoch loss:  nan
# -----
# Epoch 79:
#
# Mean epoch loss:  nan
# -----
# Epoch 80:
#
# Mean epoch loss:  nan
# -----
# Epoch 81:
#
# Mean epoch loss:  0.1950085387836106
# -----
# Epoch 82:
#
# Mean epoch loss:  nan
# -----
# Epoch 83:
#
# Mean epoch loss:  nan
# -----
# Epoch 84:
#
# Mean epoch loss:  nan
# -----
# Epoch 85:
#
# Mean epoch loss:  nan
# -----
# Epoch 86:
#
# Mean epoch loss:  0.20232587292024465
# -----
# Epoch 87:
#
# Mean epoch loss:  0.18742787339898678
# -----
# Epoch 88:
#
# Mean epoch loss:  0.19965535685176325
# -----
# Epoch 89:
#
# Mean epoch loss:  nan
# -----
# Epoch 90:
#
# Mean epoch loss:  nan
# -----
# Epoch 91:
#
# Mean epoch loss:  0.1948074106895147
# -----
# Epoch 92:
#
# Mean epoch loss:  nan
# -----
# Epoch 93:
#
# Mean epoch loss:  nan
# -----
# Epoch 94:
#
# Mean epoch loss:  0.1962690987791779
# -----
# Epoch 95:
#
# Mean epoch loss:  0.19930491579052445
# -----
# Epoch 96:
#
# Mean epoch loss:  nan
# -----
# Epoch 97:
#
# Mean epoch loss:  0.19943428071825306
# -----
# Epoch 98:
#
# Mean epoch loss:  nan
# -----
# Epoch 99:
#
# Mean epoch loss:  nan

# %%
graphic_evaluation(net, element, phase)
# Out:
# Fe successfully selected!
